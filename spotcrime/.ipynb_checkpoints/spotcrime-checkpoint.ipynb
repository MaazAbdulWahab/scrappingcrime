# %%
import requests
import bs4
from bs4 import BeautifulSoup as soup
import datetime
from pytz import all_timezones
import pytz
from pymongo import MongoClient

# %%
client = MongoClient('mongodb://localhost:27017/')
db = client['crime_app']
table=db['crimes']

# %%
editable_list=db['list_of_resources']
editable_list=editable_list.find({'Network':'SpotCrime'})
list_of_cities=[]
for element in editable_list:
    list_of_cities.append(element['Location'])
list_of_cities
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b93befd1c89e> in <module>
# ----> 1 editable_list=db['list_of_resources']
#       2 editable_list=editable_list.find({'Network':'SpotCrime'})
#       3 list_of_cities=[]
#       4 for element in editable_list:
#       5     list_of_cities.append(element['Location'])
#
# NameError: name 'db' is not defined

# %%
if len(list_of_cities) == 0:
    print('Could Not fetch list of cities from database')

# %%
datetime_now=datetime.datetime.now(tz=pytz.timezone('EET'))
print(datetime_now)
delta=datetime.timedelta(days=10)
datetime_now=datetime_now-delta
print(datetime_now)
cursor=table.find({'Network':'SpotCrime','Date':{'$gte':datetime.datetime.strptime(datetime_now.strftime('%Y-%m-%d %H:%M:%S'),'%Y-%m-%d %H:%M:%S')}})
# Out:
# 2020-09-25 11:11:09.526615+03:00
# 2020-09-15 11:11:09.526615+03:00

# %%
old_list=[]
for row in cursor:
    
    old_list.append(row['Key'])

# %%
old_list
# Out:
# ['https://spotcrime.com/crime/146870959-a0e8048db56f8657a02ecca964d28065',
#  'https://spotcrime.com/crime/146870960-ab60f7c880787c401dcb2263ef5e5dd2',
#  'https://spotcrime.com/crime/146900337-a060100be1df9cf657d1afa47e3db9b5',
#  'https://spotcrime.com/crime/146890828-2c61fb09f6b14982e44d0b1fb7cca235',
#  'https://spotcrime.com/crime/146890825-060a43df8e3d3c8f7afc87fbea1eb0ac',
#  'https://spotcrime.com/crime/146890821-50bf1c51cf0a68bace7da1398975e9b9',
#  'https://spotcrime.com/crime/146890818-633777aa5dcdd5ab49e2a8bfd4776928',
#  'https://spotcrime.com/crime/146890814-fb1792bcb104bf2834c132fd78d034bc',
#  'https://spotcrime.com/crime/146890811-14e7e06d2ac6bf340d91a6b79f37bb4b',
#  'https://spotcrime.com/crime/146890804-a466783e2b575bf1c3b353daf1b4ae41',
#  'https://spotcrime.com/crime/146890808-7e2d116e1b4ed96084099b14a352e4cc',
#  'https://spotcrime.com/crime/146890798-ff51b4175887130a778a1add06085074',
#  'https://spotcrime.com/crime/146890801-48a3c34befd96bfe7400410e312a01ca',
#  'https://spotcrime.com/crime/146890795-32a9c8559afba95fa3489aed5f9b1a6b',
#  'https://spotcrime.com/crime/146890791-611994c30f0afe096a4c2bc09c3ee0e0',
#  'https://spotcrime.com/crime/146890789-bec2f96322bf867fcdcff2d8fbd751df',
#  'https://spotcrime.com/crime/146890786-340152f421bc13970a7ee3cbda00ed41',
#  'https://spotcrime.com/crime/146890777-dbd04f0ec46603086787c327ed98549b',
#  'https://spotcrime.com/crime/146890781-95d7e8354fffccd9d367fb1d8fda423b',
#  'https://spotcrime.com/crime/146890774-c217a743649cb2a3851fcfd07080f038',
#  'https://spotcrime.com/crime/146890770-722ca0145b5887f54b9c45585d6d07be',
#  'https://spotcrime.com/crime/146890766-34fabe4be739eaddd22615f7701c11e9',
#  'https://spotcrime.com/crime/146890762-b8561ebd29894cd084265c681a3eec99',
#  'https://spotcrime.com/crime/146890759-0ecb2add46af961a5dbc235477c5b0e5',
#  'https://spotcrime.com/crime/146890756-01709f39992f21a982eaf84ac7035f32',
#  'https://spotcrime.com/crime/146890754-cf2ab55afe3c38097fd988f4fb2e6f35',
#  'https://spotcrime.com/crime/146890751-45d040934f26e3a5ef4ef95a0f3ea965',
#  'https://spotcrime.com/crime/146890742-2ab9147a9dc24cc11d98dc4ce0126755',
#  'https://spotcrime.com/crime/146890747-1ba8510435a0602aef6a68ccb9456940',
#  'https://spotcrime.com/crime/146890745-e73ae7f3889523da26f0b6edef02f404',
#  'https://spotcrime.com/crime/146890737-8a27d311f432966e858759381e15e176',
#  'https://spotcrime.com/crime/146890734-1f37e27adf13e724ce720575f3911c8f',
#  'https://spotcrime.com/crime/146890732-4ad707a4b5c95d3e530d91722511da6e',
#  'https://spotcrime.com/crime/146890730-d31731d418f31724e485fee559fc5f80',
#  'https://spotcrime.com/crime/146890725-564ac2220441f120d645873d497753e2',
#  'https://spotcrime.com/crime/146890723-fcdebb4d8cf64a9cd9ba6688c34dd56d',
#  'https://spotcrime.com/crime/146890720-77aa16f50ba05a653284c9882aa3106d',
#  'https://spotcrime.com/crime/146890718-3498df8df4d0487bbff4752a929928b5',
#  'https://spotcrime.com/crime/146890708-2b586aab0abfdd80bbee1694b1c21209',
#  'https://spotcrime.com/crime/146890715-f5be698c76fb4107a062b38346f30a82',
#  'https://spotcrime.com/crime/146890710-d62786d81fd6749f2989ec6d15db06e4',
#  'https://spotcrime.com/crime/146890712-c25bac79b76fdf1c420c59b83ef58aea',
#  'https://spotcrime.com/crime/146890703-00da605e6e0184eeed710a3abc6debb4',
#  'https://spotcrime.com/crime/146890706-e2b4b689b44ed172fc80bab0531086f8',
#  'https://spotcrime.com/crime/146890701-2217128fbb16055e3fb7b476044e6fb7',
#  'https://spotcrime.com/crime/146890698-f04c309d8dc8a1464202ce27408328d5',
#  'https://spotcrime.com/crime/146890695-a280da29773f5afe4370ff8d71c78d31',
#  'https://spotcrime.com/crime/146890692-de1f1ae171a9ed037bcf558313f26fc5',
#  'https://spotcrime.com/crime/146890688-44667fd876e590680b9bf515b870d3a7',
#  'https://spotcrime.com/crime/146890686-905eec22f8c2c87bbaeacbffc3d9b9c7',
#  'https://spotcrime.com/crime/146890682-6e31b44f15b2871c3ea6c25b7cbd4c0d',
#  'https://spotcrime.com/crime/146890673-3fa38ed7e3bc01604fa79c070921461e',
#  'https://spotcrime.com/crime/146890667-88b2f4afa50d4d6fa00d4d050fdfa601',
#  'https://spotcrime.com/crime/146971979-4d23d5ce1d76471446e36355378ad254',
#  'https://spotcrime.com/crime/146970559-3b058ab895a9991b2e0a0a062090243f',
#  'https://spotcrime.com/crime/146969848-ff3dd5ad0f0b5abd3e85fe228690dfc2',
#  'https://spotcrime.com/crime/146968552-509fe61fc7b40df4e3a7b52e028e1069',
#  'https://spotcrime.com/crime/146966678-61696290573306426446f04a0515c34f',
#  'https://spotcrime.com/crime/146965670-ccd683c1b5a39d4c1d3f93962cea1f03',
#  'https://spotcrime.com/crime/146966609-b00174e3c22ed1e210096f60c17ea3aa',
#  'https://spotcrime.com/crime/146964700-a97b8b6764c4e087529f428b33dc7249',
#  'https://spotcrime.com/crime/146961583-09d3e7bf3c1132169286d45df25b6909',
#  'https://spotcrime.com/crime/146960505-185156afc149b6e896f2d7967e0f9030',
#  'https://spotcrime.com/crime/146960023-35ac1c58d103242dd17f74aebf5aa465',
#  'https://spotcrime.com/crime/146960097-773fd87f7ee43c331a166451b2922d9f',
#  'https://spotcrime.com/crime/146959699-f699e6ceed4e9fc138e60265a6eef6f0',
#  'https://spotcrime.com/crime/146959389-1c46dccde75f27ef58c2ad975f3eb50f',
#  'https://spotcrime.com/crime/146959447-78188a8f9f9422ce34f3bdde779c841a',
#  'https://spotcrime.com/crime/146959434-819418482e00f2df34bc5670af1b58da',
#  'https://spotcrime.com/crime/146959715-f21ce5389930c87dac3a643c092f1114',
#  'https://spotcrime.com/crime/146957785-d5fb97d78bdcec1aa25c4c8625de4925',
#  'https://spotcrime.com/crime/146957421-8d6a45b4f9834293f6a7443a7ab41874',
#  'https://spotcrime.com/crime/146956068-668bb5a3eb956d5099cda7451cc873e5',
#  'https://spotcrime.com/crime/146956719-6b1d1aef639b7ae1699324f61e7dca27',
#  'https://spotcrime.com/crime/146956099-1c277641137cd00b646f7fb0b9dae243',
#  'https://spotcrime.com/crime/146970346-fd8af29bbff36f01a099dfe492fe2c71',
#  'https://spotcrime.com/crime/146965892-68b339fdd987e8a5793a028b7a9e7134',
#  'https://spotcrime.com/crime/146966343-2d92d1409d55d3603fcbf2c0e3afaef8',
#  'https://spotcrime.com/crime/146963877-e27cec0f69b02151cc4bb70f6de9ff05',
#  'https://spotcrime.com/crime/146961729-401fe35b0dadfbed87777de0d390b0f3',
#  'https://spotcrime.com/crime/146960450-fef55f61722537182b150cf3fdf0c4e8',
#  'https://spotcrime.com/crime/146959941-52fbc46d1db25ad8e40e89ba50b1577f',
#  'https://spotcrime.com/crime/146957636-c7c4bb41c693ad1d0409792fe46da23f',
#  'https://spotcrime.com/crime/146957900-4eb4f612325db1282fba76d988bcd967',
#  'https://spotcrime.com/crime/146956626-55d4504a3bcbcf49010482c514ba79c1',
#  'https://spotcrime.com/crime/146956171-4118501cd15889ac98f40ed4850fa5c8',
#  'https://spotcrime.com/crime/146956532-07422daddedd2ce108188fcd525afd1f',
#  'https://spotcrime.com/crime/146969229-06db1784472068c19926bce9c9114827',
#  'https://spotcrime.com/crime/146969561-9f843c3f5047c855bf99f1ddd48fe108',
#  'https://spotcrime.com/crime/146967855-bc64cd16564e03edef8455e3c828e346',
#  'https://spotcrime.com/crime/146966422-5d4b556364b6318138e64e4db3fd8ec0',
#  'https://spotcrime.com/crime/146966711-b012f200181b4022e112d419a366ece3',
#  'https://spotcrime.com/crime/146966428-6c868da834e65599383508d755b29cd9',
#  'https://spotcrime.com/crime/146966539-a99eda5a4e79fbf75fe9dae8ed052e6b',
#  'https://spotcrime.com/crime/146966480-7f3ab92e6047d767ea874a79a4ba515a',
#  'https://spotcrime.com/crime/146966527-a0283aa8b3d3530bf32044705d989dda',
#  'https://spotcrime.com/crime/146966497-2a7974cc75a85811780568c52aafd8a2',
#  'https://spotcrime.com/crime/146965876-912a2c9aae77f961c859c6552e7ab710',
#  'https://spotcrime.com/crime/146961120-15690b64f86359e007b3d836cf62e86f',
#  'https://spotcrime.com/crime/146960971-08ca7ad7a64a73ca1e3b705e3e54d190',
#  'https://spotcrime.com/crime/146961116-94c9993de25195faacaeb3fb6389c4c6',
#  'https://spotcrime.com/crime/146960317-778625557acb2fce40022432465be88a',
#  'https://spotcrime.com/crime/146959894-807e6a47c404d08776ad095682b2b88b',
#  'https://spotcrime.com/crime/146968742-108c5a5bbb3384f5594b6c0523648fe4',
#  'https://spotcrime.com/crime/146968683-a256e5514c4305f3c9d39b0958e0a750',
#  'https://spotcrime.com/crime/146968677-321bb776e6f33b0f077b9a7154851924',
#  'https://spotcrime.com/crime/146968756-be4c5ee999935c8e145d4a400476148f',
#  'https://spotcrime.com/crime/146968494-2fd25d446333e5f8898f4fce3fbe4d04',
#  'https://spotcrime.com/crime/146968419-d8e9ad1d296525ca58f1a493d606f28b',
#  'https://spotcrime.com/crime/146968529-1ad586d69ebd81c5454fe0e5714909b7',
#  'https://spotcrime.com/crime/146968427-9c07b68aa8a047d80a52bf088d5301dd',
#  'https://spotcrime.com/crime/146968407-315535c44fa583ab14964f61991cc7fd',
#  'https://spotcrime.com/crime/146968506-ee3aaf3c14b18cef082eeb8d5f1eae53',
#  'https://spotcrime.com/crime/146968412-91137250a38baa5d4c5ef15c5119c1b3',
#  'https://spotcrime.com/crime/146968393-2611c01713ddb8e89fc6e2a7bcb80a11',
#  'https://spotcrime.com/crime/146968512-8e695b17f7c2970bf719cc2b280969a1',
#  'https://spotcrime.com/crime/146968442-6f20313689580417ad4d52216298380d',
#  'https://spotcrime.com/crime/146968424-0fdbb8055d08aa2c622764de75850dbc',
#  'https://spotcrime.com/crime/146968588-dc0a33d09e0ce562859fba23a0073210',
#  'https://spotcrime.com/crime/146968460-ca893cf49683d32264aa27cc4fc44fc9',
#  'https://spotcrime.com/crime/146968546-b350c899daf842e276ec5aceb4267d60',
#  'https://spotcrime.com/crime/146968554-651b29fc7f7a0e3cb299ba97ea1870cf',
#  'https://spotcrime.com/crime/146968558-abef63dcb2146a89778e5a59e7642f59',
#  'https://spotcrime.com/crime/146968517-e0b8877ad9ded5f5ecbae9b8effb98ba',
#  'https://spotcrime.com/crime/146968651-565e8e7575ecf0a98a4903e71a458b95',
#  'https://spotcrime.com/crime/146968604-9473e6ccbd7c5c44821a23afa87347e9',
#  'https://spotcrime.com/crime/146968526-e091b7fa24cf3262b98dfb8cd76eee1d',
#  'https://spotcrime.com/crime/146968509-86929b692beef4bef8845ad47124079d',
#  'https://spotcrime.com/crime/146968752-9e42f01d15d89df0c7fb158606338379',
#  'https://spotcrime.com/crime/146968477-2783df81feef1a8cfba8a926280cf82c',
#  'https://spotcrime.com/crime/146968515-193102b9e9d5eaa4b52174c23168859c',
#  'https://spotcrime.com/crime/146968750-1b5a2fe713820de83f0cebb6ddb63c79',
#  'https://spotcrime.com/crime/146968579-2c79f7d6834f18ba0135c2d38b074a0b',
#  'https://spotcrime.com/crime/146968719-a699370c59508d6be171cd116e701e71',
#  'https://spotcrime.com/crime/146968548-f438fcd9091c6c653c3aec75076a7eb1',
#  'https://spotcrime.com/crime/146968373-5fe86ff698eb337cacef573521558766',
#  'https://spotcrime.com/crime/146968436-af7b95b46ee5f95497fda4f221614d21',
#  'https://spotcrime.com/crime/146968384-b605266fdbaa477e3c471e571cd1902b',
#  'https://spotcrime.com/crime/146968544-7d7c018935fc5a4b0f7c0f106cf22a6d',
#  'https://spotcrime.com/crime/146968624-26ed275cd089b5ce87bbeda54692ab7b',
#  'https://spotcrime.com/crime/146968400-ade53d85483c5fa04071e085e985fd9a',
#  'https://spotcrime.com/crime/146968488-6aa532082edec3ea9e8598ecdd237df7',
#  'https://spotcrime.com/crime/146968568-d0696e36ea1878cdedd67babcd032ef5',
#  'https://spotcrime.com/crime/146968448-10c9921983e60758f618fd5ca7e482d1',
#  'https://spotcrime.com/crime/146968396-37574ac3fff9dcde608b2b3cd88d520d',
#  'https://spotcrime.com/crime/146968555-c5faa73653ee5f5e2f75ca2cc5bacdbe',
#  'https://spotcrime.com/crime/146968594-a6fafbf56af9da6a877a57df6a9ba494',
#  'https://spotcrime.com/crime/146968551-785f7a9c6d48dd7271327d48c8bc49be',
#  'https://spotcrime.com/crime/146968409-ed991f050b4c88f711931b1d46c75543',
#  'https://spotcrime.com/crime/146968519-61681af12b57ff856dad7bf27224508f',
#  'https://spotcrime.com/crime/146968600-51ac3fd59d59758f4d67b6fc4c414680',
#  'https://spotcrime.com/crime/146968673-6a7cd9df16257c69945299947698b45b',
#  'https://spotcrime.com/crime/146968538-5daf725c4d8cc4ff02e995a213791a86',
#  'https://spotcrime.com/crime/146968032-f39338cdc1ea9bccf000a3591ffb9882',
#  'https://spotcrime.com/crime/146968026-f6168ab56f4d08c55daf07df2d8042b5',
#  'https://spotcrime.com/crime/146968023-f19ef7424e4e32f2b4aca71827cc126e',
#  'https://spotcrime.com/crime/146968019-b04c124907bd52df55db4904bc11fe8c',
#  'https://spotcrime.com/crime/146968012-5628673e54a6d14e4b3c411fef27237d',
#  'https://spotcrime.com/crime/146968008-a20dc37397dd196883ab2a78a4d13be1',
#  'https://spotcrime.com/crime/146968003-347ac3c8645180a54769e6572216b40e',
#  'https://spotcrime.com/crime/146967997-bc7d6e8a2c391d9286da133dafbfc01b',
#  'https://spotcrime.com/crime/146967991-17454c005ea239b77d20687f09acbe89',
#  'https://spotcrime.com/crime/146967988-dcdc9be057d20d20d660eb80c8745d3d',
#  'https://spotcrime.com/crime/146967980-5f5492448ef3e40ecebddeb3f6ef77c3',
#  'https://spotcrime.com/crime/146967975-fb30aa879e591b6f9cecc4f0a771e323',
#  'https://spotcrime.com/crime/146967969-4cfd76f5121f2f4de1ba695f1c23c3cd',
#  'https://spotcrime.com/crime/146967965-01555acfc94a19350912d8d14f457b5b',
#  'https://spotcrime.com/crime/146967957-eb4c250237e0bbfdffd5f1e62edbb006',
#  'https://spotcrime.com/crime/146967960-f4b00c1ea05a0d1819d2a778e37266b0',
#  'https://spotcrime.com/crime/146967951-5d5abe62e5fc50dc5898c13383f266ac',
#  'https://spotcrime.com/crime/146967946-963d469c8e514a715431e6b8dd9817bf',
#  'https://spotcrime.com/crime/146967941-f3345ed0c980601131ba0b042e9898f2',
#  'https://spotcrime.com/crime/146967937-f544e7f3bc980f28fbc26fe2b3d9a671',
#  'https://spotcrime.com/crime/146967928-97c5e27ecdc27e897d10ebc54866178b',
#  'https://spotcrime.com/crime/146967917-9445cc1be5e8c3a1a45d2e5ca760e208',
#  'https://spotcrime.com/crime/146967923-6182c4a29cb7b4355413283ea12360b0']

# %%
list_of_links=[]
list_of_types=[]
list_of_datetime=[]
list_of_description=[]
list_of_address=[]
list_of_map_link=[]
list_of_latitude=[]
list_of_longitude=[]
cit=[]
website=[]

# %%
j=1

data=requests.get('https://spotcrime.com/browse-by-state')
data=data.content
page=soup(data,'lxml')
states_list=page.find_all('div', class_='state-page__state-container')

for city in list_of_cities:
    try:
        state=city.split(',')[1].strip().lower()
        for the_state in states_list:
            if the_state.find('a').text.strip().lower() == state.lower():
                state_link=the_state.find('a')['href']
                state_link='https://spotcrime.com'+state_link
                print(state_link)
            
    
        city=city.split(',')[0].strip().lower()
        inside_state=requests.get(state_link)
        inside_state=inside_state.content
        page_city=soup(inside_state,'lxml')
        found_cities=page_city.find('div' ,id='state-page__main-areas')
        found_cities=found_cities.find_all('a')
        for the_find in found_cities:
            if the_find.text.split(',')[0].strip().lower() == city.lower():
                city_link=the_find['href']
                city_link='https://spotcrime.com'+city_link
                print(city_link)
            
        
        crime_data=requests.get(city_link)
        crime_data=crime_data.content
        page_crime=soup(crime_data,'lxml')
        crimes=page_crime.find_all('a', class_='city-page__crime-card')
        for links in crimes:
            url=links['href']
            if url in old_list:
                raise Exception
            list_of_links.append(url)
            crimedata=requests.get(url)
            crimedata=crimedata.content
            page=soup(crimedata,'lxml')
            description=page.find('div',class_='crime-details-page__details-section')
            description=description.find_all('p')
            types=description[0].text
            types=types.split(':')[1].strip()
            
            list_of_types.append(types)
            date_time=description[1].text
    
            date_time=date_time.split(':')
        
            date_time=date_time[1:]
            
            date_time=date_time[0].strip()+':'+date_time[1].strip()
            
            date_time_obj = datetime.datetime.strptime(date_time, '%m/%d/%Y %I:%M %p')
            tz = pytz.timezone('US/Central')
            date_time_obj = date_time_obj.replace(tzinfo=tz)
            date_time_obj=  date_time_obj.astimezone(pytz.timezone('EET'))
        
            list_of_datetime.append(date_time_obj)
            desc_of_crime=description[2].text
            desc_of_crime=desc_of_crime.split(':')[1].strip()
            #print(desc_of_crime)
            list_of_description.append(desc_of_crime)
            address=description[3].text
            address=address.split(':')[1].strip()
            #print(address)
            list_of_address.append(address)
            map_of_crime=page.find('a' , class_='crime-details-page__google-map-btn')
            map_of_crime=map_of_crime['href']
            #print(map_of_crime)
            longitude=map_of_crime.split(' ')[1]
            #print(longitude)
            longitude=float(longitude)
            list_of_longitude.append(longitude)
            latitude=map_of_crime.split('=')[2]
            latitude=latitude.split(',')
            latitude=latitude[0]
            #print(latitude)
            latitude=float(latitude)
            list_of_latitude.append(latitude)
            list_of_map_link.append(map_of_crime)
            cit.append(city)
            website.append('spotcrime')
            document={'Key':url,'Longitude':longitude, 'Latitude':latitude, 'Location':city,'Text':desc_of_crime,'Category':types, 'Address':address
                            ,  'Date':date_time_obj, 'Network': 'SpotCrime'}
            print(j)
            j=j+1
            table.insert_one(document)
                
    except:
        print('Found in old')
        continue
# Out:
# https://spotcrime.com/NY
# https://spotcrime.com/NY/New%20York
# Found in old
# https://spotcrime.com/CA
# https://spotcrime.com/CA/Los%20Angeles
# Found in old
# https://spotcrime.com/CA
# https://spotcrime.com/CA/San%20Francisco
# Found in old

# %%
import pandas as pd

# %%
df=pd.DataFrame({'Key': list_of_links,'Type':list_of_types,'Description':list_of_description,'Address':list_of_address,'DateTime':list_of_datetime,'Latitude':list_of_latitude,'Longitude':list_of_longitude, 'City':cit,'Website':website})

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: [Key, Type, Description, Address, DateTime, Latitude, Longitude, City, Website]
# Index: []

# %%
df.to_csv('SpotCrime.csv', index=False)
